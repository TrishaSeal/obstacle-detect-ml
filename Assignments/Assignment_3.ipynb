# %%
# Prelim code - Reduce console verbose
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import PIL
import pathlib

import matplotlib.pyplot as plt


import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.utils import image_dataset_from_directory

# %%
dataDir = pathlib.Path('./archive')
imgHeight = 256
imgWidth = 256

trainData = image_dataset_from_directory(dataDir.joinpath('train_data'), image_size = (imgHeight, imgWidth))
testData = image_dataset_from_directory(dataDir.joinpath('test_data'), image_size = (imgHeight, imgWidth))

classNames = trainData.class_names
# Out:
# Found 150 files belonging to 16 classes.
# Found 157 files belonging to 16 classes.

# %%
# Normalizing data
normLayer = layers.Rescaling(1./255)

normTrainData = trainData.map(lambda x, y: (normLayer(x), y))
plt.figure(figsize=(10, 10))
for images, labels in normTrainData.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(classNames[labels[i]])
        plt.axis('off')

# %% [markdown]
# Images appear black since all rgb values are scaled from [0, 255] to [0, 1]
#
# ## Defining and Fitting CNN Model

# %%
model = Sequential([
    layers.Conv2D(16, 3, input_shape=(imgHeight, imgWidth, 3), padding='same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, input_shape=(imgHeight, imgWidth, 3), padding='same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, input_shape=(imgHeight, imgWidth, 3), padding='same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(len(classNames))
])
model.compile(optimizer = 'adam', loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True), metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 256, 256, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_2 (Dense)             (None, 128)               8388736
#
#  dense_3 (Dense)             (None, 16)                2064
#
# =================================================================
# Total params: 8,414,384
# Trainable params: 8,414,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
epoch = 25
history = model.fit(normTrainData, epochs = epoch)
# Out:
# Epoch 1/25
# 5/5 [==============================] - 9s 223ms/step - loss: 3.3330 - accuracy: 0.1400
# Epoch 2/25
# 5/5 [==============================] - 2s 46ms/step - loss: 2.5034 - accuracy: 0.2067
# Epoch 3/25
# 5/5 [==============================] - 2s 55ms/step - loss: 2.2925 - accuracy: 0.2400
# Epoch 4/25
# 5/5 [==============================] - 2s 59ms/step - loss: 1.9974 - accuracy: 0.3400
# Epoch 5/25
# 5/5 [==============================] - 2s 50ms/step - loss: 1.7057 - accuracy: 0.4600
# Epoch 6/25
# 5/5 [==============================] - 2s 53ms/step - loss: 1.3954 - accuracy: 0.5400
# Epoch 7/25
# 5/5 [==============================] - 2s 43ms/step - loss: 1.0206 - accuracy: 0.7200
# Epoch 8/25
# 5/5 [==============================] - 2s 59ms/step - loss: 0.7769 - accuracy: 0.7800
# Epoch 9/25
# 5/5 [==============================] - 2s 55ms/step - loss: 0.5022 - accuracy: 0.8533
# Epoch 10/25
# 5/5 [==============================] - 2s 56ms/step - loss: 0.5008 - accuracy: 0.9133
# Epoch 11/25
# 5/5 [==============================] - 2s 48ms/step - loss: 0.6473 - accuracy: 0.8867
# Epoch 12/25
# 5/5 [==============================] - 3s 58ms/step - loss: 0.3740 - accuracy: 0.9133
# Epoch 13/25
# 5/5 [==============================] - 3s 54ms/step - loss: 0.1961 - accuracy: 0.9600
# Epoch 14/25
# 5/5 [==============================] - 2s 53ms/step - loss: 0.1257 - accuracy: 0.9733
# Epoch 15/25
# 5/5 [==============================] - 2s 54ms/step - loss: 0.1272 - accuracy: 0.9667
# Epoch 16/25
# 5/5 [==============================] - 2s 65ms/step - loss: 0.0660 - accuracy: 0.9867
# Epoch 17/25
# 5/5 [==============================] - 2s 56ms/step - loss: 0.0420 - accuracy: 0.9933
# Epoch 18/25
# 5/5 [==============================] - 2s 44ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 19/25
# 5/5 [==============================] - 2s 31ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 20/25
# 5/5 [==============================] - 2s 45ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 21/25
# 5/5 [==============================] - 2s 43ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 22/25
# 5/5 [==============================] - 2s 57ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 23/25
# 5/5 [==============================] - 2s 56ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 24/25
# 5/5 [==============================] - 2s 52ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 25/25
# 5/5 [==============================] - 3s 57ms/step - loss: 0.0014 - accuracy: 1.0000

# %% [markdown]
# ## Evaluating Model Performance
#
# ### Training Results

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs = range(epoch)

plt.figure(figsize = (10, 10))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, label = 'Training Accuracy')
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label = 'Training Loss')
plt.show()

# %% [markdown]
# ### Testing on new Data

# %%
normTestData = testData.map(lambda x, y: (normLayer(x), y))

actualLabs = list()
for image, label in normTestData:
    for l in label:
    	actualLabs.append(l)

pred = model.predict(normTestData)
for i in range(len(pred)):
    score = tf.nn.softmax(pred[i])
    print("Prediction: " + classNames[np.argmax(score)] + " ({:.2f}%)".format(100 * np.max(score)))
    print("Actual: " + classNames[actualLabs[i]])
# Out:
# 5/5 [==============================] - 3s 93ms/step
# Prediction: blasti (99.72%)
# Actual: gretit
# Prediction: bonegl (93.33%)
# Actual: jglowl
# Prediction: hsparo (28.30%)
# Actual: cmnmyn
# Prediction: indvul (66.33%)
# Actual: bonegl
# Prediction: indvul (88.58%)
# Actual: himgri
# Prediction: indvul (97.46%)
# Actual: mgprob
# Prediction: himbul (81.81%)
# Actual: lbicrw
# Prediction: himgri (100.00%)
# Actual: jglowl
# Prediction: hilpig (42.53%)
# Actual: bonegl
# Prediction: himbul (32.56%)
# Actual: rebimg
# Prediction: blasti (92.67%)
# Actual: blasti
# Prediction: rebimg (97.80%)
# Actual: blasti
# Prediction: himbul (99.90%)
# Actual: jglowl
# Prediction: indvul (69.51%)
# Actual: himbul
# Prediction: indvul (95.49%)
# Actual: wcrsrt
# Prediction: himgri (97.02%)
# Actual: indvul
# Prediction: brhkyt (94.12%)
# Actual: cmnmyn
# Prediction: himgri (85.79%)
# Actual: cmnmyn
# Prediction: himbul (99.42%)
# Actual: brhkyt
# Prediction: hilpig (35.57%)
# Actual: gretit
# Prediction: lbicrw (100.00%)
# Actual: blasti
# Prediction: blasti (84.48%)
# Actual: cbrtsh
# Prediction: cbrtsh (36.12%)
# Actual: himbul
# Prediction: himgri (78.16%)
# Actual: lbicrw
# Prediction: himbul (89.26%)
# Actual: mgprob
# Prediction: blasti (49.89%)
# Actual: hilpig
# Prediction: himbul (95.57%)
# Actual: cmnmyn
# Prediction: hilpig (80.13%)
# Actual: cbrtsh
# Prediction: himgri (97.30%)
# Actual: lbicrw
# Prediction: himgri (85.07%)
# Actual: bonegl
# Prediction: indvul (87.81%)
# Actual: brhkyt
# Prediction: rebimg (98.16%)
# Actual: himbul
# Prediction: himbul (96.48%)
# Actual: wcrsrt
# Prediction: indvul (91.72%)
# Actual: himgri
# Prediction: hilpig (52.13%)
# Actual: indvul
# Prediction: himbul (98.79%)
# Actual: hilpig
# Prediction: himbul (58.69%)
# Actual: himbul
# Prediction: cbrtsh (32.84%)
# Actual: wcrsrt
# Prediction: hilpig (67.62%)
# Actual: brhkyt
# Prediction: blasti (71.54%)
# Actual: rebimg
# Prediction: indvul (38.93%)
# Actual: himgri
# Prediction: blasti (47.05%)
# Actual: rebimg
# Prediction: indvul (97.93%)
# Actual: hsparo
# Prediction: rebimg (44.36%)
# Actual: lbicrw
# Prediction: indvul (79.45%)
# Actual: blasti
# Prediction: hilpig (99.78%)
# Actual: himbul
# Prediction: himbul (99.94%)
# Actual: mgprob
# Prediction: rebimg (94.27%)
# Actual: himgri
# Prediction: bonegl (99.82%)
# Actual: himbul
# Prediction: blasti (44.15%)
# Actual: rebimg
# Prediction: himgri (41.52%)
# Actual: cbrtsh
# Prediction: blasti (99.90%)
# Actual: hilpig
# Prediction: lbicrw (56.34%)
# Actual: bonegl
# Prediction: jglowl (63.12%)
# Actual: indvul
# Prediction: cbrtsh (58.65%)
# Actual: rebimg
# Prediction: brhkyt (99.87%)
# Actual: indvul
# Prediction: rebimg (100.00%)
# Actual: blasti
# Prediction: himgri (35.63%)
# Actual: hilpig
# Prediction: rebimg (55.40%)
# Actual: himgri
# Prediction: blasti (47.05%)
# Actual: hsparo
# Prediction: indvul (62.08%)
# Actual: himbul
# Prediction: rebimg (99.82%)
# Actual: indvul
# Prediction: indvul (90.87%)
# Actual: cbrtsh
# Prediction: himbul (64.59%)
# Actual: hilpig
# Prediction: rebimg (50.83%)
# Actual: rebimg
# Prediction: hsparo (61.90%)
# Actual: cbrtsh
# Prediction: indvul (96.29%)
# Actual: himbul
# Prediction: indvul (95.14%)
# Actual: blasti
# Prediction: bonegl (85.81%)
# Actual: indvul
# Prediction: jglowl (99.90%)
# Actual: bonegl
# Prediction: blasti (65.89%)
# Actual: mgprob
# Prediction: himgri (99.99%)
# Actual: rebimg
# Prediction: brhkyt (64.65%)
# Actual: himgri
# Prediction: lbicrw (37.60%)
# Actual: blasti
# Prediction: himgri (63.03%)
# Actual: himbul
# Prediction: himgri (99.08%)
# Actual: blasti
# Prediction: cbrtsh (73.06%)
# Actual: hsparo
# Prediction: himgri (99.97%)
# Actual: himbul
# Prediction: himbul (92.26%)
# Actual: mgprob
# Prediction: himbul (59.17%)
# Actual: rebimg
# Prediction: gretit (35.34%)
# Actual: blasti
# Prediction: blasti (86.31%)
# Actual: lbicrw
# Prediction: himbul (99.93%)
# Actual: himbul
# Prediction: hsparo (97.63%)
# Actual: cmnmyn
# Prediction: bonegl (50.53%)
# Actual: bonegl
# Prediction: himgri (95.64%)
# Actual: himgri
# Prediction: himgri (45.23%)
# Actual: cmnmyn
# Prediction: himbul (41.08%)
# Actual: hilpig
# Prediction: hsparo (81.99%)
# Actual: himbul
# Prediction: wcrsrt (48.14%)
# Actual: brhkyt
# Prediction: rebimg (99.93%)
# Actual: himbul
# Prediction: himbul (99.81%)
# Actual: himbul
# Prediction: himbul (52.82%)
# Actual: cmnmyn
# Prediction: indvul (47.40%)
# Actual: himgri
# Prediction: himgri (99.99%)
# Actual: brhkyt
# Prediction: mgprob (93.95%)
# Actual: rebimg
# Prediction: hsparo (79.61%)
# Actual: brhkyt
# Prediction: hsparo (41.07%)
# Actual: hilpig
# Prediction: mgprob (35.51%)
# Actual: himgri
# Prediction: indvul (99.06%)
# Actual: blasti
# Prediction: hsparo (94.76%)
# Actual: jglowl
# Prediction: indvul (78.48%)
# Actual: himbul
# Prediction: cbrtsh (95.11%)
# Actual: wcrsrt
# Prediction: hsparo (43.09%)
# Actual: rebimg
# Prediction: himbul (99.62%)
# Actual: himgri
# Prediction: indvul (81.84%)
# Actual: himgri
# Prediction: himbul (41.18%)
# Actual: gretit
# Prediction: hilpig (88.81%)
# Actual: himgri
# Prediction: wcrsrt (65.70%)
# Actual: himgri
# Prediction: himgri (98.47%)
# Actual: cmnmyn
# Prediction: himbul (46.44%)
# Actual: cbrtsh
# Prediction: blasti (59.24%)
# Actual: wcrsrt
# Prediction: himbul (79.13%)
# Actual: hilpig
# Prediction: indvul (95.27%)
# Actual: gretit
# Prediction: himgri (34.99%)
# Actual: jglowl
# Prediction: jglowl (59.91%)
# Actual: rebimg
# Prediction: blasti (87.76%)
# Actual: blasti
# Prediction: hsparo (92.24%)
# Actual: jglowl
# Prediction: himbul (100.00%)
# Actual: lbicrw
# Prediction: himgri (98.35%)
# Actual: hsparo
# Prediction: blasti (96.81%)
# Actual: hsparo
# Prediction: indvul (61.41%)
# Actual: mgprob
# Prediction: rebimg (95.71%)
# Actual: hsparo
# Prediction: rebimg (92.98%)
# Actual: himgri
# Prediction: rebimg (70.69%)
# Actual: wcrsrt
# Prediction: rebimg (99.98%)
# Actual: gretit
# Prediction: himbul (99.48%)
# Actual: hsparo
# Prediction: bonegl (99.58%)
# Actual: indvul
# Prediction: himbul (63.77%)
# Actual: hsparo
# Prediction: himbul (99.04%)
# Actual: himgri
# Prediction: indvul (61.24%)
# Actual: mgprob
# Prediction: blasti (99.52%)
# Actual: indvul
# Prediction: rebimg (85.73%)
# Actual: himgri
# Prediction: hilpig (36.65%)
# Actual: blasti
# Prediction: hsparo (76.63%)
# Actual: hilpig
# Prediction: blasti (50.36%)
# Actual: wcrsrt
# Prediction: himgri (31.66%)
# Actual: himbul
# Prediction: hilpig (77.33%)
# Actual: wcrsrt
# Prediction: himgri (59.52%)
# Actual: blasti
# Prediction: bonegl (99.99%)
# Actual: himbul
# Prediction: himbul (52.89%)
# Actual: wcrsrt
# Prediction: blasti (43.78%)
# Actual: hilpig
# Prediction: hsparo (93.52%)
# Actual: indvul
# Prediction: mgprob (43.80%)
# Actual: himgri
# Prediction: himgri (96.64%)
# Actual: himgri
# Prediction: himbul (43.79%)
# Actual: gretit
# Prediction: indvul (71.41%)
# Actual: bonegl
# Prediction: mgprob (94.11%)
# Actual: wcrsrt
# Prediction: hilpig (32.43%)
# Actual: himbul
# Prediction: himgri (98.72%)
# Actual: cbrtsh
# Prediction: himgri (65.30%)
# Actual: himgri
# Prediction: hilpig (48.76%)
# Actual: blasti
# Prediction: hsparo (31.29%)
# Actual: blasti
# Prediction: blasti (99.87%)
# Actual: himbul
# Prediction: rebimg (51.75%)
# Actual: hsparo
# Prediction: himgri (26.41%)
# Actual: himgri
# Prediction: hsparo (97.98%)
# Actual: gretit
